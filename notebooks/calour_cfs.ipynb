# %%
import warnings   
warnings.simplefilter("ignore") 
import matplotlib as mpl
# %matplotlib notebook
import sys
sys.path.append('/Users/Serene/calour')
import calour as cl
import numpy as np
import calour.cahelper as cah
import calour.analysis

# %%
cfs=cl.read_taxa('data/cfs.biom','data/cfs.map.txt',sparse=False, filter_orig_reads=1000)

# %%
cfs.sample_metadata.Subject.value_counts()
# Out:
# Patient    48
# Control    39
# Name: Subject, dtype: int64

# %%
cfs_sub1 = cfs.filter_min_abundance(5)
ds1 = cfs_sub1.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
bh1 = cfs_sub1.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
fbh1 = cfs_sub1.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')

# %%
cfs_sub1.sample_metadata.Subject.value_counts()
# Out:
# Patient    48
# Control    39
# Name: Subject, dtype: int64

# %%
ds1.plot_sort('Subject', databases=[],gui='jupyter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# ds1.feature_metadata

# %%
print(ds1)
print(bh1)
print(fbh1)
# Out:
# AmpliconExperiment cfs.biom with 87 samples, 52 features
# AmpliconExperiment cfs.biom with 87 samples, 16 features
# AmpliconExperiment cfs.biom with 87 samples, 43 features

# %%
len(ds1.feature_metadata.index.intersection(bh1.feature_metadata.index))
# Out:
# 16

# %%
xx=ds1.feature_metadata.index.difference(bh1.feature_metadata.index)

# %%
yy=ds1.filter_ids(xx.values)

# %%
yy.feature_metadata.columns
# Out:
# Index(['taxonomy', 'id', '_calour_diff_abundance_effect',
#        '_calour_diff_abundance_pval'],
#       dtype='object')

# %%
yy=yy.sort_by_metadata('_calour_diff_abundance_effect', axis=1)

# %%
yy.plot_sort('Subject', gui='qt5')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
bh1.plot(gui='jupyter', databases=[])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
b1=ds1.feature_metadata.index.difference(fbh1.feature_metadata.index)
b2=ds1.filter_ids(b1.values)
b2=b2.sort_by_metadata('_calour_diff_abundance_effect', axis=1)

# %%
# b2.plot_sort('Subject', gui='qt5')

# %%
cfs_sub2 = cfs_sub1.downsample('Subject', num_keep=35)
cfs_sub3 = cfs_sub1.downsample('Subject', num_keep=30)
cfs_sub4 = cfs_sub1.downsample('Subject', num_keep=25)
cfs_sub5 = cfs_sub1.downsample('Subject', num_keep=20)
cfs_sub6 = cfs_sub1.downsample('Subject', num_keep=15)
cfs_sub7 = cfs_sub1.downsample('Subject', num_keep=10)
cfs_sub8 = cfs_sub1.downsample('Subject', num_keep=5)

# %%
ds2 = cfs_sub2.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
bh2 = cfs_sub2.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
fbh2 = cfs_sub2.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')

# %%
print(ds2)
print(bh2)
print(fbh2)
# Out:
# AmpliconExperiment cfs.biom with 70 samples, 145 features
# AmpliconExperiment cfs.biom with 70 samples, 60 features
# AmpliconExperiment cfs.biom with 70 samples, 127 features

# %%
ds3 = cfs_sub3.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
bh3 = cfs_sub3.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
fbh3 = cfs_sub3.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
# Out:
# 2017-03-02 17:24:59 WARNING no significant features found
# 2017-03-02 17:24:59 WARNING no significant features found
# 2017-03-02 17:24:59 WARNING no significant features found

# %%
print(ds3)
print(bh3)
print(fbh3)
# Out:
# None
# None
# None

# %%
ds4 = cfs_sub4.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
bh4 = cfs_sub4.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
fbh4 = cfs_sub4.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
# Out:
# 2017-03-02 17:25:00 WARNING no significant features found

# %%
print(ds4)
print(bh4)
print(fbh4)
len(ds4.feature_metadata.index.intersection(fbh4.feature_metadata.index))
# Out:
# AmpliconExperiment cfs.biom with 50 samples, 14 features
# None
# AmpliconExperiment cfs.biom with 50 samples, 10 features
# 1

# %%
ds4.plot_sort('Subject', databases=[],gui='jupyter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fbh4.plot_sort('Subject', databases=[],gui='jupyter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ds5 = cfs_sub5.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
bh5 = cfs_sub5.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
fbh5 = cfs_sub5.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
# Out:
# 2017-03-02 17:25:08 WARNING no significant features found
# 2017-03-02 17:25:08 WARNING no significant features found
# 2017-03-02 17:25:08 WARNING no significant features found

# %%
print(ds5)
print(bh5)
print(fbh5)
# Out:
# None
# None
# None

# %%
ds6 = cfs_sub6.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
bh6 = cfs_sub6.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
fbh6 = cfs_sub6.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
# Out:
# 2017-03-02 17:25:09 WARNING no significant features found
# 2017-03-02 17:25:10 WARNING no significant features found
# 2017-03-02 17:25:10 WARNING no significant features found

# %%
ds7 = cfs_sub7.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
bh7 = cfs_sub7.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
fbh7 = cfs_sub7.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
# Out:
# 2017-03-02 17:25:10 WARNING no significant features found
# 2017-03-02 17:25:11 WARNING no significant features found
# 2017-03-02 17:25:11 WARNING no significant features found

# %%
ds8 = cfs_sub8.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
bh8 = cfs_sub8.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
fbh8 = cfs_sub8.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
# Out:
# 2017-03-02 17:25:12 WARNING no significant features found
# 2017-03-02 17:25:12 WARNING no significant features found

# %%
print(ds8)
print(bh8)
print(fbh8)
# Out:
# AmpliconExperiment cfs.biom with 10 samples, 9 features
# None
# None

# %%
ds8.plot_sort('Subject', databases=[],gui='jupyter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# randomness of subsample

# %%
gcd = cl.read_taxa('data/gcd.biom','data/gcd.map.txt',sparse=False)

# %%
gcd
# Out:
# AmpliconExperiment gcd.biom with 1339 samples, 9511 features

# %%
gcd_sub1 = gcd.filter_min_abundance(5)
#ds1_gcd = gcd_sub1.diff_abundance('diagnosis','IC','CD', 'UC', 'no', fdr_method='dsfdr')
bh1_gcd = gcd_sub1.diff_abundance_kw('diagnosis', 
                                  transform = None, 
                                  fdr_method='bhfdr')
#fbh1_gcd = gcd_sub1.diff_abundance('diagnosis','IC','CD', 'UC', 'no', fdr_method='filterBH')
# Out:
# [ True False False ..., False False False]
