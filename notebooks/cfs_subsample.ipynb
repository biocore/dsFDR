# %%
import warnings   
warnings.simplefilter("ignore") 
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib notebook
import sys
sys.path.append('/Users/Serene/calour')
import calour as cl
import numpy as np
import calour.cahelper as cah
import calour.analysis

from scipy.stats import sem

# %%
cfs=cl.read_taxa('data/cfs.biom','data/cfs.map.txt',sparse=False, filter_orig_reads=1000)

# %%
cfs.sample_metadata.Subject.value_counts()
# Out:
# Patient    48
# Control    39
# Name: Subject, dtype: int64

# %%
np.random.seed(31)
cfs_sub1 = cfs.filter_min_abundance(5)

# %%
cfs_sub1
# Out:
# AmpliconExperiment cfs.biom with 87 samples, 1399 features

# %%
np.random.seed(31)
ds9 = []
bh9 = []
fbh9 = []

for i in range(100):
    cfs_sub9 = cfs_sub1.downsample('Subject', num_keep=39)
    ds = cfs_sub9.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub9.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub9.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    ds9.append(sig_ds)
    bh9.append(sig_bh)
    fbh9.append(sig_fbh)
    
DS9 = np.mean(ds9)
BH9 = np.mean(bh9)
FBH9 = np.mean(fbh9)
err_DS9 = sem(ds9)  # unbiased standard error
err_BH9 = sem(bh9)
err_FBH9 = sem(fbh9)

print(DS9, BH9, FBH9)
print(err_DS9, err_BH9, err_FBH9)
# Out:
# 2017-03-04 15:41:08 WARNING no significant features found
# 2017-03-04 15:41:14 WARNING no significant features found
# 2017-03-04 15:41:19 WARNING no significant features found
# 2017-03-04 15:41:25 WARNING no significant features found
# 2017-03-04 15:41:26 WARNING no significant features found
# 2017-03-04 15:41:32 WARNING no significant features found
# 2017-03-04 15:41:33 WARNING no significant features found
# 2017-03-04 15:41:39 WARNING no significant features found
# 2017-03-04 15:41:39 WARNING no significant features found
# 2017-03-04 15:41:39 WARNING no significant features found
# 2017-03-04 15:41:45 WARNING no significant features found
# 2017-03-04 15:41:56 WARNING no significant features found
# 2017-03-04 15:42:02 WARNING no significant features found
# 2017-03-04 15:42:05 WARNING no significant features found
# 2017-03-04 15:42:10 WARNING no significant features found
# 2017-03-04 15:42:13 WARNING no significant features found
# ...

# %%
np.random.seed(31)
ds2 = []
bh2 = []
fbh2 = []

for i in range(100):
    cfs_sub2 = cfs_sub1.downsample('Subject', num_keep=35)
    ds = cfs_sub2.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub2.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub2.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    ds2.append(sig_ds)
    bh2.append(sig_bh)
    fbh2.append(sig_fbh)
    
DS2 = np.mean(ds2)
BH2 = np.mean(bh2)
FBH2 = np.mean(fbh2)
err_DS2 = sem(ds2)  # unbiased standard error
err_BH2 = sem(bh2)
err_FBH2 = sem(fbh2)

print(DS2, BH2, FBH2)
print(err_DS2, err_BH2, err_FBH2)
# Out:
# 2017-03-04 15:43:25 WARNING no significant features found
# 2017-03-04 15:43:32 WARNING no significant features found
# 2017-03-04 15:43:38 WARNING no significant features found
# 2017-03-04 15:43:52 WARNING no significant features found
# 2017-03-04 15:44:02 WARNING no significant features found
# 2017-03-04 15:44:05 WARNING no significant features found
# 2017-03-04 15:44:08 WARNING no significant features found
# 2017-03-04 15:44:11 WARNING no significant features found
# 2017-03-04 15:44:14 WARNING no significant features found
# 2017-03-04 15:44:24 WARNING no significant features found
# 2017-03-04 15:44:25 WARNING no significant features found
# 2017-03-04 15:44:25 WARNING no significant features found
# 2017-03-04 15:44:28 WARNING no significant features found
# 2017-03-04 15:44:44 WARNING no significant features found
# 2017-03-04 15:45:09 WARNING no significant features found
# 2017-03-04 15:45:18 WARNING no significant features found
# ...

# %%
np.random.seed(31)
ds3 = []
bh3 = []
fbh3 = []

for i in range(100):
    cfs_sub3 = cfs_sub1.downsample('Subject', num_keep=30)
    ds = cfs_sub3.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub3.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub3.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    
    ds3.append(sig_ds)
    bh3.append(sig_bh)
    fbh3.append(sig_fbh)
    
DS3 = np.mean(ds3)
BH3 = np.mean(bh3)
FBH3 = np.mean(fbh3)
err_DS3 = sem(ds3)
err_BH3 = sem(bh3)
err_FBH3 = sem(fbh3)

print(DS3, BH3, FBH3)
print(err_DS3, err_BH3, err_FBH3)
# Out:
# 2017-03-04 15:46:01 WARNING no significant features found
# 2017-03-04 15:46:08 WARNING no significant features found
# 2017-03-04 15:46:09 WARNING no significant features found
# 2017-03-04 15:46:09 WARNING no significant features found
# 2017-03-04 15:46:11 WARNING no significant features found
# 2017-03-04 15:46:12 WARNING no significant features found
# 2017-03-04 15:46:18 WARNING no significant features found
# 2017-03-04 15:46:19 WARNING no significant features found
# 2017-03-04 15:46:21 WARNING no significant features found
# 2017-03-04 15:46:22 WARNING no significant features found
# 2017-03-04 15:46:22 WARNING no significant features found
# 2017-03-04 15:46:25 WARNING no significant features found
# 2017-03-04 15:46:25 WARNING no significant features found
# 2017-03-04 15:46:26 WARNING no significant features found
# 2017-03-04 15:46:29 WARNING no significant features found
# 2017-03-04 15:46:31 WARNING no significant features found
# ...

# %%
np.random.seed(31)
ds4 = []
bh4 = []
fbh4 = []

for i in range(100):
    cfs_sub4 = cfs_sub1.downsample('Subject', num_keep=25)
    ds = cfs_sub4.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub4.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub4.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    
    ds4.append(sig_ds)
    bh4.append(sig_bh)
    fbh4.append(sig_fbh)
    
DS4 = np.mean(ds4)
BH4 = np.mean(bh4)
FBH4 = np.mean(fbh4)
err_DS4 = sem(ds4)
err_BH4 = sem(bh4)
err_FBH4 = sem(fbh4)

print(DS4, BH4, FBH4)
print(err_DS4, err_BH4, err_FBH4)
# Out:
# 2017-03-04 15:48:26 WARNING no significant features found
# 2017-03-04 15:48:27 WARNING no significant features found
# 2017-03-04 15:48:29 WARNING no significant features found
# 2017-03-04 15:48:32 WARNING no significant features found
# 2017-03-04 15:48:33 WARNING no significant features found
# 2017-03-04 15:48:36 WARNING no significant features found
# 2017-03-04 15:48:36 WARNING no significant features found
# 2017-03-04 15:48:36 WARNING no significant features found
# 2017-03-04 15:48:39 WARNING no significant features found
# 2017-03-04 15:48:40 WARNING no significant features found
# 2017-03-04 15:48:45 WARNING no significant features found
# 2017-03-04 15:48:48 WARNING no significant features found
# 2017-03-04 15:48:49 WARNING no significant features found
# 2017-03-04 15:48:50 WARNING no significant features found
# 2017-03-04 15:48:50 WARNING no significant features found
# 2017-03-04 15:48:52 WARNING no significant features found
# ...

# %%
np.random.seed(31)
ds5 = []
bh5 = []
fbh5 = []

for i in range(100):
    cfs_sub5 = cfs_sub1.downsample('Subject', num_keep=20)
    ds = cfs_sub5.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub5.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub5.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index) 
    
    ds5.append(sig_ds)
    bh5.append(sig_bh)
    fbh5.append(sig_fbh)
    
DS5 = np.mean(ds5)
BH5 = np.mean(bh5)
FBH5 = np.mean(fbh5)
err_DS5 = sem(ds5)
err_BH5 = sem(bh5)
err_FBH5 = sem(fbh5)
print(DS5, BH5, FBH5)
print(err_DS5, err_BH5, err_FBH5)
# Out:
# 2017-03-04 15:50:53 WARNING no significant features found
# 2017-03-04 15:50:55 WARNING no significant features found
# 2017-03-04 15:50:56 WARNING no significant features found
# 2017-03-04 15:50:57 WARNING no significant features found
# 2017-03-04 15:50:58 WARNING no significant features found
# 2017-03-04 15:50:59 WARNING no significant features found
# 2017-03-04 15:50:59 WARNING no significant features found
# 2017-03-04 15:51:00 WARNING no significant features found
# 2017-03-04 15:51:03 WARNING no significant features found
# 2017-03-04 15:51:04 WARNING no significant features found
# 2017-03-04 15:51:06 WARNING no significant features found
# 2017-03-04 15:51:06 WARNING no significant features found
# 2017-03-04 15:51:07 WARNING no significant features found
# 2017-03-04 15:51:08 WARNING no significant features found
# 2017-03-04 15:51:09 WARNING no significant features found
# 2017-03-04 15:51:09 WARNING no significant features found
# ...

# %%
np.random.seed(31)
ds6 = []
bh6 = []
fbh6 = []

for i in range(100):
    cfs_sub6 = cfs_sub1.downsample('Subject', num_keep=15)
    ds = cfs_sub6.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub6.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub6.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    
    ds6.append(sig_ds)
    bh6.append(sig_bh)
    fbh6.append(sig_fbh)
DS6 = np.mean(ds6)
BH6 = np.mean(bh6)
FBH6 = np.mean(fbh6)
err_DS6 = sem(ds6)
err_BH6 = sem(bh6)
err_FBH6 = sem(fbh6)
print(DS6, BH6, FBH6)
print(err_DS6, err_BH6, err_FBH6)
# Out:
# 2017-03-04 15:53:14 WARNING no significant features found
# 2017-03-04 15:53:15 WARNING no significant features found
# 2017-03-04 15:53:16 WARNING no significant features found
# 2017-03-04 15:53:16 WARNING no significant features found
# 2017-03-04 15:53:17 WARNING no significant features found
# 2017-03-04 15:53:17 WARNING no significant features found
# 2017-03-04 15:53:17 WARNING no significant features found
# 2017-03-04 15:53:18 WARNING no significant features found
# 2017-03-04 15:53:18 WARNING no significant features found
# 2017-03-04 15:53:18 WARNING no significant features found
# 2017-03-04 15:53:19 WARNING no significant features found
# 2017-03-04 15:53:19 WARNING no significant features found
# 2017-03-04 15:53:19 WARNING no significant features found
# 2017-03-04 15:53:20 WARNING no significant features found
# 2017-03-04 15:53:22 WARNING no significant features found
# 2017-03-04 15:53:22 WARNING no significant features found
# ...

# %%
np.random.seed(31)
ds7 = []
bh7 = []
fbh7 = []

for i in range(100):
    cfs_sub7 = cfs_sub1.downsample('Subject', num_keep=10)
    ds = cfs_sub7.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub7.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub7.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    
    ds7.append(sig_ds)
    bh7.append(sig_bh)
    fbh7.append(sig_fbh)
DS7 = np.mean(ds7)
BH7 = np.mean(bh7)
FBH7 = np.mean(fbh7)
err_DS7 = sem(ds7)
err_BH7 = sem(bh7)
err_FBH7 = sem(fbh7)
print(DS7, BH7, FBH7)
print(err_DS7, err_BH7, err_FBH7)
# Out:
# 2017-03-04 15:55:22 WARNING no significant features found
# 2017-03-04 15:55:23 WARNING no significant features found
# 2017-03-04 15:55:23 WARNING no significant features found
# 2017-03-04 15:55:23 WARNING no significant features found
# 2017-03-04 15:55:24 WARNING no significant features found
# 2017-03-04 15:55:24 WARNING no significant features found
# 2017-03-04 15:55:24 WARNING no significant features found
# 2017-03-04 15:55:26 WARNING no significant features found
# 2017-03-04 15:55:26 WARNING no significant features found
# 2017-03-04 15:55:26 WARNING no significant features found
# 2017-03-04 15:55:27 WARNING no significant features found
# 2017-03-04 15:55:27 WARNING no significant features found
# 2017-03-04 15:55:27 WARNING no significant features found
# 2017-03-04 15:55:28 WARNING no significant features found
# 2017-03-04 15:55:28 WARNING no significant features found
# 2017-03-04 15:55:29 WARNING no significant features found
# ...

# %%
np.random.seed(31)
ds8 = []
bh8 = []
fbh8 = []

for i in range(100):
    cfs_sub8 = cfs_sub1.downsample('Subject', num_keep=5)
    ds = cfs_sub8.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub8.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub8.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    
    ds8.append(sig_ds)
    bh8.append(sig_bh)
    fbh8.append(sig_fbh)
DS8 = np.mean(ds8)
BH8 = np.mean(bh8)
FBH8 = np.mean(fbh8)
err_DS8 = sem(ds8)
err_BH8 = sem(bh8)
err_FBH8 = sem(fbh8)
print(DS8, BH8, FBH8)
print(err_DS8, err_BH8, err_FBH8)
# Out:
# 2017-03-04 15:57:09 WARNING no significant features found
# 2017-03-04 15:57:10 WARNING no significant features found
# 2017-03-04 15:57:10 WARNING no significant features found
# 2017-03-04 15:57:11 WARNING no significant features found
# 2017-03-04 15:57:11 WARNING no significant features found
# 2017-03-04 15:57:11 WARNING no significant features found
# 2017-03-04 15:57:11 WARNING no significant features found
# 2017-03-04 15:57:11 WARNING no significant features found
# 2017-03-04 15:57:12 WARNING no significant features found
# 2017-03-04 15:57:12 WARNING no significant features found
# 2017-03-04 15:57:12 WARNING no significant features found
# 2017-03-04 15:57:13 WARNING no significant features found
# 2017-03-04 15:57:13 WARNING no significant features found
# 2017-03-04 15:57:13 WARNING no significant features found
# 2017-03-04 15:57:14 WARNING no significant features found
# 2017-03-04 15:57:14 WARNING no significant features found
# ...

# %%
samples = np.hstack([39, np.arange(35, 0, -5)])
otu_ds = np.array([DS9, DS2, DS3, DS4, DS5, DS6, DS7, DS8])
otu_bh = np.array([BH9, BH2, BH3, BH4, BH5, BH6, BH7, BH8])
otu_fbh = np.array([FBH9, FBH2, FBH3, FBH4, FBH5, FBH6, FBH7, FBH8])

err_ds = np.array([err_DS9, err_DS2, err_DS3, err_DS4, err_DS5, err_DS6, err_DS7, err_DS8])
err_bh = np.array([err_BH9, err_BH2, err_BH3, err_BH4, err_BH5, err_BH6, err_BH7, err_BH8])
err_fbh = np.array([err_FBH9, err_FBH2, err_FBH3, err_FBH4, err_FBH5, FBH6, err_FBH7, err_FBH8])

# %%
plt.figure()
plt.errorbar(samples, otu_ds, yerr=err_ds, color = 'red')
plt.errorbar(samples+0.1, otu_fbh, yerr=err_fbh, color = 'orange')
plt.errorbar(samples+0.2, otu_bh, yerr=err_bh, color = 'blue')
plt.xlabel('sub sample size')
plt.ylabel('number of significant bacteria')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
samples2 = np.hstack([np.arange(35, 0, -5)])
otu_ds2 = np.array([DS2, DS3, DS4, DS5, DS6, DS7, DS8])
otu_bh2 = np.array([BH2, BH3, BH4, BH5, BH6, BH7, BH8])
otu_fbh2 = np.array([FBH2, FBH3, FBH4, FBH5, FBH6, FBH7, FBH8])

err_ds2 = np.array([err_DS2, err_DS3, err_DS4, err_DS5, err_DS6, err_DS7, err_DS8])
err_bh2 = np.array([err_BH2, err_BH3, err_BH4, err_BH5, err_BH6, err_BH7, err_BH8])
err_fbh2 = np.array([err_FBH2, err_FBH3, err_FBH4, err_FBH5, FBH6, err_FBH7, err_FBH8])

# %%
plt.figure()
plt.errorbar(samples2, otu_ds2, yerr=err_ds2, color = 'red')
plt.errorbar(samples2+0.1, otu_fbh2, yerr=err_fbh2, color = 'orange')
plt.errorbar(samples2+0.2, otu_bh2, yerr=err_bh2, color = 'blue')
plt.xlabel('sub sample size')
plt.ylabel('number of significant bacteria')
# Out:
# <img src="data:image/png;base64,..." width="640">
