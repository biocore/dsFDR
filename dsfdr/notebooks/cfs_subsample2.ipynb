# %%
import warnings   
warnings.simplefilter("ignore") 
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib notebook
import sys
sys.path.append('/Users/Serene/calour')
import calour as cl
import numpy as np
import calour.cahelper as cah
import calour.analysis

from scipy.stats import sem

# %%
cfs=cl.read_taxa('data/cfs.biom','data/cfs.map.txt',sparse=False, filter_orig_reads=1000)

# %%
cfs.sample_metadata.Subject.value_counts()
# Out:
# Patient    48
# Control    39
# Name: Subject, dtype: int64

# %%
np.random.seed(10)
cfs_sub1 = cfs.filter_min_abundance(5)

# %%
np.random.seed(10)
ds9 = []
bh9 = []
fbh9 = []

for i in range(20):
    cfs_sub9 = cfs_sub1.downsample('Subject', num_keep=39)
    ds = cfs_sub9.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub9.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub9.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    ds9.append(sig_ds)
    bh9.append(sig_bh)
    fbh9.append(sig_fbh)
    
DS9 = np.mean(ds9)
BH9 = np.mean(bh9)
FBH9 = np.mean(fbh9)
err_DS9 = sem(ds9)  # unbiased standard error
err_BH9 = sem(bh9)
err_FBH9 = sem(fbh9)

print(DS9, BH9, FBH9)
print(err_DS9, err_BH9, err_FBH9)
# Out:
# 2017-03-03 22:26:42 WARNING no significant features found
# 2017-03-03 22:26:53 WARNING no significant features found
# 2017-03-03 22:26:54 WARNING no significant features found
# 2017-03-03 22:26:54 WARNING no significant features found
# 2017-03-03 22:26:55 WARNING no significant features found
# 2017-03-03 22:26:56 WARNING no significant features found
# 2017-03-03 22:26:56 WARNING no significant features found
# 2017-03-03 22:27:03 WARNING no significant features found
# 2017-03-03 22:27:07 WARNING no significant features found
# 2017-03-03 22:27:10 WARNING no significant features found
# 2017-03-03 22:27:14 WARNING no significant features found
# 84.55 36.95 69.3
# 12.0909872915 8.16006804667 11.4315123096

# %%
np.random.seed(10)
ds2 = []
bh2 = []
fbh2 = []

for i in range(20):
    cfs_sub2 = cfs_sub1.downsample('Subject', num_keep=35)
    ds = cfs_sub2.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub2.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub2.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    ds2.append(sig_ds)
    bh2.append(sig_bh)
    fbh2.append(sig_fbh)
    
DS2 = np.mean(ds2)
BH2 = np.mean(bh2)
FBH2 = np.mean(fbh2)
err_DS2 = sem(ds2)  # unbiased standard error
err_BH2 = sem(bh2)
err_FBH2 = sem(fbh2)

print(DS2, BH2, FBH2)
print(err_DS2, err_BH2, err_FBH2)
# Out:
# 2017-03-03 21:50:36 WARNING no significant features found
# 2017-03-03 21:50:41 WARNING no significant features found
# 129.65 64.75 109.2
# 11.4416770486 8.54273313839 11.0616930274

# %%
np.random.seed(10)
ds3 = []
bh3 = []
fbh3 = []

for i in range(10):
    cfs_sub3 = cfs_sub1.downsample('Subject', num_keep=30)
    ds = cfs_sub3.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub3.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub3.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    
    ds3.append(sig_ds)
    bh3.append(sig_bh)
    fbh3.append(sig_fbh)
    
DS3 = np.mean(ds3)
BH3 = np.mean(bh3)
FBH3 = np.mean(fbh3)
err_DS3 = sem(ds3)
err_BH3 = sem(bh3)
err_FBH3 = sem(fbh3)

print(DS3, BH3, FBH3)
print(err_DS3, err_BH3, err_FBH3)
# Out:
# 2017-03-03 21:47:59 WARNING no significant features found
# 2017-03-03 21:48:09 WARNING no significant features found
# 84.9 25.6 66.4
# 11.116004478 9.24145250729 11.4699607672

# %%
np.random.seed(10)
ds4 = []
bh4 = []
fbh4 = []

for i in range(10):
    cfs_sub4 = cfs_sub1.downsample('Subject', num_keep=25)
    ds = cfs_sub4.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub4.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub4.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    
    ds4.append(sig_ds)
    bh4.append(sig_bh)
    fbh4.append(sig_fbh)
    
DS4 = np.mean(ds4)
BH4 = np.mean(bh4)
FBH4 = np.mean(fbh4)
err_DS4 = sem(ds4)
err_BH4 = sem(bh4)
err_FBH4 = sem(fbh4)

print(DS4, BH4, FBH4)
print(err_DS4, err_BH4, err_FBH4)
# Out:
# 2017-03-03 21:48:10 WARNING no significant features found
# 2017-03-03 21:48:22 WARNING no significant features found
# 2017-03-03 21:48:23 WARNING no significant features found
# 2017-03-03 21:48:24 WARNING no significant features found
# 76.4 21.7 59.8
# 9.14719143295 6.89452278584 10.8860767344

# %%
np.random.seed(10)
ds5 = []
bh5 = []
fbh5 = []

for i in range(10):
    cfs_sub5 = cfs_sub1.downsample('Subject', num_keep=20)
    ds = cfs_sub5.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub5.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub5.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index) 
    
    ds5.append(sig_ds)
    bh5.append(sig_bh)
    fbh5.append(sig_fbh)
    
DS5 = np.mean(ds5)
BH5 = np.mean(bh5)
FBH5 = np.mean(fbh5)
err_DS5 = sem(ds5)
err_BH5 = sem(bh5)
err_FBH5 = sem(fbh5)
print(DS5, BH5, FBH5)
print(err_DS5, err_BH5, err_FBH5)
# Out:
# 2017-03-03 21:48:25 WARNING no significant features found
# 2017-03-03 21:48:27 WARNING no significant features found
# 2017-03-03 21:48:27 WARNING no significant features found
# 2017-03-03 21:48:28 WARNING no significant features found
# 2017-03-03 21:48:28 WARNING no significant features found
# 2017-03-03 21:48:28 WARNING no significant features found
# 2017-03-03 21:48:31 WARNING no significant features found
# 2017-03-03 21:48:33 WARNING no significant features found
# 2017-03-03 21:48:34 WARNING no significant features found
# 2017-03-03 21:48:35 WARNING no significant features found
# 2017-03-03 21:48:36 WARNING no significant features found
# 2017-03-03 21:48:36 WARNING no significant features found
# 2017-03-03 21:48:37 WARNING no significant features found
# 2017-03-03 21:48:37 WARNING no significant features found
# 2017-03-03 21:48:37 WARNING no significant features found
# 2017-03-03 21:48:38 WARNING no significant features found
# 2017-03-03 21:48:39 WARNING no significant features found
# 2017-03-03 21:48:39 WARNING no significant features found
# 31.6 4.8 21.1
# 14.612931868 4.8 10.9315547334

# %%
np.random.seed(10)
ds6 = []
bh6 = []
fbh6 = []

for i in range(10):
    cfs_sub6 = cfs_sub1.downsample('Subject', num_keep=15)
    ds = cfs_sub6.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub6.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub6.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    
    ds6.append(sig_ds)
    bh6.append(sig_bh)
    fbh6.append(sig_fbh)
DS6 = np.mean(ds6)
BH6 = np.mean(bh6)
FBH6 = np.mean(fbh6)
err_DS6 = sem(ds6)
err_BH6 = sem(bh6)
err_FBH6 = sem(fbh6)
print(DS6, BH6, FBH6)
print(err_DS6, err_BH6, err_FBH6)
# Out:
# 2017-03-03 21:48:40 WARNING no significant features found
# 2017-03-03 21:48:41 WARNING no significant features found
# 2017-03-03 21:48:41 WARNING no significant features found
# 2017-03-03 21:48:42 WARNING no significant features found
# 2017-03-03 21:48:42 WARNING no significant features found
# 2017-03-03 21:48:43 WARNING no significant features found
# 2017-03-03 21:48:43 WARNING no significant features found
# 2017-03-03 21:48:44 WARNING no significant features found
# 2017-03-03 21:48:44 WARNING no significant features found
# 2017-03-03 21:48:46 WARNING no significant features found
# 2017-03-03 21:48:47 WARNING no significant features found
# 2017-03-03 21:48:47 WARNING no significant features found
# 2017-03-03 21:48:48 WARNING no significant features found
# 2017-03-03 21:48:49 WARNING no significant features found
# 2017-03-03 21:48:50 WARNING no significant features found
# 2017-03-03 21:48:50 WARNING no significant features found
# 2017-03-03 21:48:51 WARNING no significant features found
# 2017-03-03 21:48:51 WARNING no significant features found
# 2017-03-03 21:48:52 WARNING no significant features found
# 2017-03-03 21:48:53 WARNING no significant features found
# 2017-03-03 21:48:53 WARNING no significant features found
# 14.0 0.0 5.2
# 5.01331560281 0.0 2.78008792827

# %%
np.random.seed(10)
ds7 = []
bh7 = []
fbh7 = []

for i in range(10):
    cfs_sub7 = cfs_sub1.downsample('Subject', num_keep=10)
    ds = cfs_sub7.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub7.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub7.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    
    ds7.append(sig_ds)
    bh7.append(sig_bh)
    fbh7.append(sig_fbh)
DS7 = np.mean(ds7)
BH7 = np.mean(bh7)
FBH7 = np.mean(fbh7)
err_DS7 = sem(ds7)
err_BH7 = sem(bh7)
err_FBH7 = sem(fbh7)
print(DS7, BH7, FBH7)
print(err_DS7, err_BH7, err_FBH7)
# Out:
# 2017-03-03 21:48:54 WARNING no significant features found
# 2017-03-03 21:48:54 WARNING no significant features found
# 2017-03-03 21:48:54 WARNING no significant features found
# 2017-03-03 21:48:55 WARNING no significant features found
# 2017-03-03 21:48:55 WARNING no significant features found
# 2017-03-03 21:48:55 WARNING no significant features found
# 2017-03-03 21:48:57 WARNING no significant features found
# 2017-03-03 21:48:57 WARNING no significant features found
# 2017-03-03 21:48:58 WARNING no significant features found
# 2017-03-03 21:48:59 WARNING no significant features found
# 2017-03-03 21:48:59 WARNING no significant features found
# 2017-03-03 21:49:00 WARNING no significant features found
# 2017-03-03 21:49:00 WARNING no significant features found
# 2017-03-03 21:49:01 WARNING no significant features found
# 2017-03-03 21:49:02 WARNING no significant features found
# 2017-03-03 21:49:02 WARNING no significant features found
# 2017-03-03 21:49:03 WARNING no significant features found
# 2017-03-03 21:49:03 WARNING no significant features found
# 2017-03-03 21:49:04 WARNING no significant features found
# 2017-03-03 21:49:04 WARNING no significant features found
# 2017-03-03 21:49:04 WARNING no significant features found
# 2017-03-03 21:49:05 WARNING no significant features found
# 2017-03-03 21:49:05 WARNING no significant features found
# 2017-03-03 21:49:05 WARNING no significant features found
# 4.0 0.0 0.4
# 1.55634900399 0.0 0.4

# %%
np.random.seed(10)
ds8 = []
bh8 = []
fbh8 = []

for i in range(10):
    cfs_sub8 = cfs_sub1.downsample('Subject', num_keep=5)
    ds = cfs_sub8.diff_abundance('Subject','Control','Patient',fdr_method='dsfdr')
    bh = cfs_sub8.diff_abundance('Subject','Control','Patient',fdr_method='bhfdr')
    fbh = cfs_sub8.diff_abundance('Subject','Control','Patient',fdr_method='filterBH')
    
    if ds is None:
        sig_ds = 0
    else:
        sig_ds = len(ds.feature_metadata.index)
    if bh is None:
        sig_bh = 0
    else:
        sig_bh = len(bh.feature_metadata.index)
    if fbh is None:
        sig_fbh = 0
    else:
        sig_fbh = len(fbh.feature_metadata.index)
        
    
    ds8.append(sig_ds)
    bh8.append(sig_bh)
    fbh8.append(sig_fbh)
DS8 = np.mean(ds8)
BH8 = np.mean(bh8)
FBH8 = np.mean(fbh8)
err_DS8 = sem(ds8)
err_BH8 = sem(bh8)
err_FBH8 = sem(fbh8)
print(DS8, BH8, FBH8)
print(err_DS8, err_BH8, err_FBH8)
# Out:
# 2017-03-03 21:49:06 WARNING no significant features found
# 2017-03-03 21:49:06 WARNING no significant features found
# 2017-03-03 21:49:07 WARNING no significant features found
# 2017-03-03 21:49:07 WARNING no significant features found
# 2017-03-03 21:49:07 WARNING no significant features found
# 2017-03-03 21:49:08 WARNING no significant features found
# 2017-03-03 21:49:08 WARNING no significant features found
# 2017-03-03 21:49:08 WARNING no significant features found
# 2017-03-03 21:49:09 WARNING no significant features found
# 2017-03-03 21:49:09 WARNING no significant features found
# 2017-03-03 21:49:10 WARNING no significant features found
# 2017-03-03 21:49:10 WARNING no significant features found
# 2017-03-03 21:49:11 WARNING no significant features found
# 2017-03-03 21:49:11 WARNING no significant features found
# 2017-03-03 21:49:11 WARNING no significant features found
# 2017-03-03 21:49:12 WARNING no significant features found
# 2017-03-03 21:49:12 WARNING no significant features found
# 2017-03-03 21:49:12 WARNING no significant features found
# 2017-03-03 21:49:13 WARNING no significant features found
# 2017-03-03 21:49:13 WARNING no significant features found
# 2017-03-03 21:49:13 WARNING no significant features found
# 2017-03-03 21:49:14 WARNING no significant features found
# 2017-03-03 21:49:14 WARNING no significant features found
# 2017-03-03 21:49:14 WARNING no significant features found
# 2017-03-03 21:49:15 WARNING no significant features found
# 2017-03-03 21:49:15 WARNING no significant features found
# 2017-03-03 21:49:15 WARNING no significant features found
# 2017-03-03 21:49:16 WARNING no significant features found
# 2017-03-03 21:49:16 WARNING no significant features found
# 0.2 0.0 0.0
# 0.2 0.0 0.0

# %%
samples = np.hstack([39, np.arange(35, 0, -5)])
otu_ds = np.array([DS9, DS2, DS3, DS4, DS5, DS6, DS7, DS8])
otu_bh = np.array([BH9, BH2, BH3, BH4, BH5, BH6, BH7, BH8])
otu_fbh = np.array([FBH9, FBH2, FBH3, FBH4, FBH5, FBH6, FBH7, FBH8])

err_ds = np.array([err_DS9, err_DS2, err_DS3, err_DS4, err_DS5, err_DS6, err_DS7, err_DS8])
err_bh = np.array([err_BH9, err_BH2, err_BH3, err_BH4, err_BH5, err_BH6, err_BH7, err_BH8])
err_fbh = np.array([err_FBH9, err_FBH2, err_FBH3, err_FBH4, err_FBH5, FBH6, err_FBH7, err_FBH8])

# %%
plt.figure()
plt.errorbar(samples, otu_ds, yerr=err_ds, color = 'red')
plt.errorbar(samples+0.1, otu_fbh, yerr=err_fbh, color = 'orange')
plt.errorbar(samples+0.2, otu_bh, yerr=err_bh, color = 'blue')
plt.xlabel('sub sample size')
plt.ylabel('number of significant bacteria')
# Out:
# <img src="data:image/png;base64,..." width="640">
